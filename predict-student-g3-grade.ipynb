# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/student-grade-prediction/student-mat.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
#convert all binary label to 0 and 1
df["school"] = (df["school"] == "MS").astype(int)
df["sex"] = (df["sex"] == "M").astype(int) #return true if sex is "M" and convert it into integer
df["address"] = (df["address"] == "U").astype(int)
df["famsize"] = (df["famsize"] == "GT3").astype(int)
df["Pstatus"] = (df["Pstatus"] == "T").astype(int)
df["schoolsup"] = (df["schoolsup"] == "yes").astype(int)
df["famsup"] = (df["famsup"] == "yes").astype(int)
df["paid"] = (df["paid"] == "yes").astype(int)
df["activities"] = (df["activities"] == "yes").astype(int)
df["nursery"] = (df["nursery"] == "yes").astype(int)
df["higher"] = (df["higher"] == "yes").astype(int)
df["internet"] = (df["internet"] == "yes").astype(int)
df["romantic"] = (df["romantic"] == "yes").astype(int)

# %%
df.iloc[0]
# Out:
# school              0
# sex                 0
# age                18
# address             1
# famsize             1
# Pstatus             0
# Medu                4
# Fedu                4
# Mjob          at_home
# Fjob          teacher
# reason         course
# guardian       mother
# traveltime          2
# studytime           2
# failures            0
# schoolsup           1
# famsup              0
# paid                0
# activities          0
# nursery             1
# higher              1
# internet            0
# romantic            0
# famrel              4
# freetime            3
# goout               4
# Dalc                1
# Walc                1
# health              3
# absences            6
# G1                  5
# G2                  6
# G3                  6
# Name: 0, dtype: object

# %%
from sklearn.model_selection import train_test_split

y = df["G3"]

features = ["school", "sex", "age", "address", "Pstatus", "Medu", "Fedu", "studytime", "schoolsup", "famsup", "paid", "activities", "higher", "internet", "Dalc", "Walc", "health", "absences", "G1", "G2"]
X = df[features]

X_train, X_valid, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error


model = RandomForestRegressor(random_state=1)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=1)

# %%
prediction = model.predict(X_valid)
mae = mean_absolute_error(y_valid, prediction)
print(mae)

for i in range(len(prediction)):
    print(f"actual value: {y_valid.iloc[i]}, predicted value: {prediction[i]}")
# Out:
# 1.0677215189873415
# actual value: 14, predicted value: 14.22
# actual value: 10, predicted value: 10.59
# actual value: 9, predicted value: 9.66
# actual value: 15, predicted value: 15.64
# actual value: 16, predicted value: 16.31
# actual value: 12, predicted value: 12.28
# actual value: 14, predicted value: 13.0
# actual value: 11, predicted value: 10.4
# actual value: 9, predicted value: 9.21
# actual value: 15, predicted value: 15.27
# actual value: 10, predicted value: 8.58
# actual value: 11, predicted value: 11.44
# actual value: 10, predicted value: 10.92
# actual value: 8, predicted value: 8.26
# actual value: 15, predicted value: 15.18
# actual value: 14, predicted value: 14.06
# actual value: 12, predicted value: 13.05
# actual value: 0, predicted value: 7.43
# actual value: 10, predicted value: 9.14
# actual value: 16, predicted value: 15.09
# actual value: 0, predicted value: 3.83
# actual value: 0, predicted value: 0.35
# actual value: 8, predicted value: 3.45
# ...
